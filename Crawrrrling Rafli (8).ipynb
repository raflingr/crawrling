# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import chromedriver_autoinstaller
import csv
import time

# %%
#INSTALL BROWSER SUCH CHROME OR EDGE
chromedriver_autoinstaller.install()

#USE THE INSTALLED BROWSER FOR SELENIUM
browser = webdriver.Chrome()

# %%
data = []

for index in range (1,4):
    browser.get(f'https://www.tiket.com/homes/villa/indonesia/region/east-java-108001534490276152/page-{index}')
    time.sleep(5)
    soup = BeautifulSoup(browser.page_source,"lxml")
    rows = soup.find_all('div', class_='hotel-card seo-card')
    
    for row in rows:
        nama_villa = row.find(class_='title ellipsis').text
        lokasi_villa = row.find(class_='location ellipsis').text
        rating = row.find(class_='tiket-rating')
        if rating:
            rating = rating.text
        impress = row.find(class_='tiket-impression')
        if impress:
            impress = impress.text
        harga = row.find(class_='after-price')
        if harga:
            harga = harga.text
        deskripsi = row.find(class_='desc-price')
        if deskripsi:
            deskripsi = deskripsi.text
        df = {
            'Name': nama_villa,
            'Location': lokasi_villa,
            'Rating': rating,
            'Impression': impress,
            'Price': harga,
            'Description': deskripsi,
            }
        data.append(df)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                      Name      Location Rating Impression  \
# 0                 The Cendana Villas Batu  Batu, Malang    4.1       Good
# 1                      Villa Pyramid Batu  Batu, Malang   None       None
# 2            Villa Carmela by Kingspark 8  Batu, Malang    4.6  Fantastic
# 3                        The Villaku Batu  Batu, Malang   None       None
# 4                       Villa Green Apple  Batu, Malang    3.5       Okay
# ..                                    ...           ...    ...        ...
# 145  Great Living at Villa Green Pochinki  Batu, Malang    3.0       Okay
# 146    Villa Weekend by Masterpiece Villa  Batu, Malang    4.7  Fantastic
# 147            Villa Kastara at H7 Kayana  Batu, Malang    4.9  Fantastic
# 148                            Villa kita  Batu, Malang    4.4       Good
# 149                     Omah hinggil batu  Batu, Malang   None       None
#
#               Price          Description
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with columns 'Title', 'Price', and 'Rating'

# Save the DataFrame to a CSV file
df.to_csv('Data Villa di Indonesia 2023.csv', index=False)
